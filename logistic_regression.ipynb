# %% [markdown]
# <a href="https://colab.research.google.com/github/haridassaiprakash/Machine_Learning/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic_train.csv")

# %%
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   name          850 non-null    object
#  3   sex           850 non-null    object
#  4   age           676 non-null    float64
#  5   sibsp         850 non-null    int64
#  6   parch         850 non-null    int64
#  7   ticket        850 non-null    object
#  8   fare          849 non-null    float64
#  9   cabin         191 non-null    object
#  10  embarked      849 non-null    object
#  11  boat          308 non-null    object
#  12  body          73 non-null     float64
#  13  home.dest     464 non-null    object
#  14  survived      850 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 99.7+ KB

# %%
df.describe()
# Out:
#        passenger_id     pclass         age       sibsp       parch  \
# count    850.000000  850.00000  676.000000  850.000000  850.000000
# mean     662.816471    2.32000   29.519847    0.522353    0.382353
# std      380.751936    0.83853   14.562243    1.112132    0.879511
# min        1.000000    1.00000    0.166700    0.000000    0.000000
# 25%      332.250000    2.00000   20.000000    0.000000    0.000000
# 50%      676.500000    3.00000   28.000000    0.000000    0.000000
# 75%      992.250000    3.00000   37.000000    1.000000    0.000000
# max     1307.000000    3.00000   80.000000    8.000000    9.000000
#
#              fare        body    survived
# count  849.000000   73.000000  850.000000
# mean    34.012701  165.821918    0.368235
# std     53.705779   99.068487    0.482610
# min      0.000000    4.000000    0.000000
# 25%      7.895800   75.000000    0.000000
# 50%     14.108300  166.000000    0.000000
# 75%     31.000000  260.000000    1.000000
# ...

# %%
df.isnull().sum()
# Out:
# passenger_id      0
# pclass            0
# name              0
# sex               0
# age             174
# sibsp             0
# parch             0
# ticket            0
# fare              1
# cabin           659
# embarked          1
# boat            542
# body            777
# home.dest       386
# survived          0
# dtype: int64

# %%
df1=df.drop(['boat', 'body','home.dest','cabin'], axis = 1)

# %%
df1.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare embarked  survived
# 0  female   NaN      0      0  335432   7.7333        Q         1
# 1    male  38.0      0      0  315089   8.6625        S         0
# 2  female  30.0      1      1  345773  24.1500        S         0
# 3  female  54.0      1      3   29105  23.0000        S         1
# 4    male  40.0      0      0   28221  13.0000        S         0

# %%
df1['age'].fillna(df1['age'].mean(), inplace=True)

# %%
print(df1['embarked'].mode())
# Out:
# 0    S
# dtype: object

# %%
df1['embarked'].fillna(df1['embarked'].mode()[0], inplace=True)

# %%
df1.replace({'sex':{'male':0,'female':1}, 'embarked':{'S':0,'C':1,'Q':2}}, inplace=True)

# %%
df1.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#    sex        age  sibsp  parch  ticket     fare  embarked  survived
# 0    1  29.519847      0      0  335432   7.7333         2         1
# 1    0  38.000000      0      0  315089   8.6625         0         0
# 2    1  30.000000      1      1  345773  24.1500         0         0
# 3    1  54.000000      1      3   29105  23.0000         0         1
# 4    0  40.000000      0      0   28221  13.0000         0         0

# %%
X = df.loc[:,['passenger_id','pclass','age','ticket','fare','embarked']].values
y = df.loc[:,['survived']].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=2)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d768f88d541e> in <module>()
# ----> 1 model.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...
